# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Rating_curve = pd.read_csv ('/Users/shg096/Desktop/Rating_Crve_05BB001.csv')
measurment   = pd.read_csv ('/Users/shg096/Desktop/measurment_05BB001.csv')

print(Rating_curve)
print(measurment)
# Out:
#      Unnamed: 0  stage  dicharge
# 0             0  1.450    4.1000
# 1             1  1.530    4.9000
# 2             2  1.630    6.4000
# 3             3  1.760    9.0000
# 4             4  1.870   12.3000
# ..          ...    ...       ...
# 110         110  1.610    4.3310
# 111         111  2.099   22.9100
# 112         112  2.117   24.9527
# 113         113  2.136   27.2500
# 114         114  3.600  437.3500
#
# [115 rows x 3 columns]
#      Unnamed: 0  stage  dicharge
# 0             0  1.904     13.50
# 1             1  0.000      0.00
# 2             2  3.011    193.00
# 3             3  2.741    125.00
# 4             4  0.000      0.00
# ..          ...    ...       ...
# 289         289  1.938      7.96
# 290         290  2.015     13.70
# 291         291  2.052     10.90
# 292         292  3.190    239.00
# 293         293  3.554    307.00
#
# [294 rows x 3 columns]

# %%
# plot

plt.figure(figsize=(20,10))

plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.grid()

plt.scatter(Rating_curve['stage'], Rating_curve['dicharge'], label='Rating Curve')

plt.scatter(measurment['stage'], measurment['dicharge'], label = 'Measurement')

plt.legend(loc= 2,prop={'size': 30})

plt.xlim(1, 4.5) 

plt.title ('Bow at Banff; 05BB001', size= 30)

plt.savefig ('/Users/shg096/Desktop/Rating_Curve_vs_Measurement_Bow_Banff_05BB001.png')
